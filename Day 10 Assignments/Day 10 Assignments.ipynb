# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Given hypothesis

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Jupyter Notebooks\\AI ML Program\\Day 10'

# %%
#launching and verifying
df=pd.read_csv('general_data.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
#Data Treatment
df.isnull() #for checking if any null value is there.
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
df.duplicated() #For checking if any repeated record is there
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
df.duplicated() #For checking if any repeated record is there
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
#univariate analysis
df_2=df[['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
       'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
       'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
       'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()

df_2.head()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# std       1.106689   47068.888559            2.498887           3.659108
# min       1.000000   10090.000000            0.000000          11.000000
# 25%       1.000000   29110.000000            1.000000          12.000000
#
# ...

# %%
df_2.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count     8.000000          8.000000     8.000000       8.000000     8.000000
# mean    580.382139        560.037193   553.617107     552.000000  2364.525209
# std    1547.475750       1555.644466  1558.214607    1558.867446  1589.080548
# min       9.133301          1.000000     1.000000       0.000000     1.000000
# 25%      27.000000          5.750000     1.755983       1.000000  1230.713755
# 50%      36.461905          8.648771     2.956463       1.000000  2205.500000
# 75%      47.250000         17.750000     4.250000       1.000000  3583.312500
# max    4410.000000       4410.000000  4410.000000    4410.000000  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count     8.000000       8.000000            8.000000           8.000000
# mean    553.146329   61086.025186          551.524215         563.608579
# ...

# %%
df_2.median()
# Out:
# Age                           36.461905
# DistanceFromHome               8.648771
# Education                      2.956463
# EmployeeCount                  1.000000
# EmployeeID                  2205.500000
# JobLevel                       2.031973
# MonthlyIncome              48129.444280
# NumCompaniesWorked             2.596859
# PercentSalaryHike             14.604762
# StandardHours                  8.000000
# StockOptionLevel               0.925942
# TotalWorkingYears             10.639968
# TrainingTimesLastYear          2.899660
# YearsAtCompany                 6.566649
# YearsSinceLastPromotion        2.593878
# YearsWithCurrManager           3.845228
# dtype: float64

# %%
df_2.mode()
# Out:
#            Age  DistanceFromHome    Education  EmployeeCount  EmployeeID  \
# 0     9.133301          1.000000     1.000000            1.0      2205.5
# 1    18.000000          2.000000     1.023933            NaN      4410.0
# 2    30.000000          7.000000     2.000000            NaN         NaN
# 3    36.000000          8.105026     2.912925            NaN         NaN
# 4    36.923810          9.192517     3.000000            NaN         NaN
# 5    43.000000         14.000000     4.000000            NaN         NaN
# 6    60.000000         29.000000     5.000000            NaN         NaN
# 7  4410.000000       4410.000000  4410.000000            NaN         NaN
#
#    JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 0       1.0    4410.000000            0.000000           3.659108
# 1       NaN   10090.000000            1.000000          11.000000
# 2       NaN   29110.000000            2.000000          12.000000
# ...

# %%
df_2.skew()
# Out:
# Age                        2.827868
# DistanceFromHome           2.828249
# Education                  2.828423
# EmployeeCount              2.828427
# EmployeeID                 0.068262
# JobLevel                   2.828423
# MonthlyIncome              1.860748
# NumCompaniesWorked         2.828410
# PercentSalaryHike          2.828341
# StandardHours              2.828409
# StockOptionLevel           2.828425
# TotalWorkingYears          2.828096
# TrainingTimesLastYear      2.828420
# YearsAtCompany             2.828061
# YearsSinceLastPromotion    2.828372
# YearsWithCurrManager       2.828364
# dtype: float64

# %%
box_plot=df.Age


plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2622fb019c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26230c3af48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26230c2ec48>],
#  'medians': [<matplotlib.lines.Line2D at 0x26230c41fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26230c49a08>],
#  'means': []}

# %% [markdown]
# # Original data

# %%
import pandas as pd
df=pd.read_csv('general_data.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
#original data

df[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
# Out:
#                Age  DistanceFromHome    Education  MonthlyIncome  \
# count  4410.000000       4410.000000  4410.000000    4410.000000
# mean     36.923810          9.192517     2.912925   65029.312925
# std       9.133301          8.105026     1.023933   47068.888559
# min      18.000000          1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000   29110.000000
# 50%      36.000000          7.000000     3.000000   49190.000000
# 75%      43.000000         14.000000     4.000000   83800.000000
# max      60.000000         29.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4391.000000        4410.000000        4401.000000
# mean             2.694830          15.209524          11.279936
# std              2.498887           3.659108           7.782222
# min              0.000000          11.000000           0.000000
# ...

# %%
#Sample from original data of size 25


df[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].sample(25).describe()
# Out:
#              Age  DistanceFromHome  Education  MonthlyIncome  \
# count  25.000000         25.000000  25.000000      25.000000
# mean   35.760000          7.520000   2.880000   69628.400000
# std     9.588535          7.377443   1.092398   50590.240633
# min    25.000000          1.000000   1.000000   18590.000000
# 25%    28.000000          2.000000   2.000000   28360.000000
# 50%    31.000000          5.000000   3.000000   42940.000000
# 75%    39.000000          8.000000   4.000000  103770.000000
# max    58.000000         25.000000   4.000000  175840.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count           25.000000          25.000000          25.000000
# mean             2.040000          16.600000           9.760000
# std              2.406242           4.031129           8.608523
# min              0.000000          11.000000           1.000000
# 25%              1.000000          13.000000           4.000000
# ...

# %%
#Attrited
df_1 = df.loc[df['Attrition'] == 'Yes']
df_1_desc=df_1[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
df_1_desc
# Out:
#               Age  DistanceFromHome   Education  MonthlyIncome  \
# count  711.000000        711.000000  711.000000     711.000000
# mean    33.607595          9.012658    2.877637   61682.616034
# std      9.675693          7.772368    1.014233   44792.067695
# min     18.000000          1.000000    1.000000   10090.000000
# 25%     28.000000          2.000000    2.000000   28440.000000
# 50%     32.000000          7.000000    3.000000   49080.000000
# 75%     39.000000         15.000000    4.000000   71040.000000
# max     58.000000         29.000000    5.000000  198590.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count          707.000000         711.000000         709.000000
# mean             2.936351          15.481013           8.255289
# std              2.678774           3.775289           7.164018
# min              0.000000          11.000000           0.000000
# 25%              1.000000          12.000000           3.000000
# ...

# %%
df_1[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].sample(25).describe() #Taking a sample out of population of attrited employees
# Out:
#             Age  DistanceFromHome  Education  MonthlyIncome  \
# count  25.00000         25.000000  25.000000      25.000000
# mean   32.64000         10.320000   2.920000   53094.800000
# std     9.18731          8.905616   1.077033   36938.295408
# min    18.00000          1.000000   1.000000   20700.000000
# 25%    28.00000          2.000000   2.000000   27410.000000
# 50%    31.00000          8.000000   3.000000   43190.000000
# 75%    35.00000         17.000000   4.000000   59160.000000
# max    55.00000         28.000000   5.000000  173280.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count           25.000000          25.000000          24.000000
# mean             2.480000          15.720000           7.708333
# std              2.002498           3.259857           6.017938
# min              1.000000          11.000000           0.000000
# 25%              1.000000          13.000000           1.750000
# ...

# %%
df_2 = df.loc[df['Attrition'] == 'No']
df_2[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
# Out:
#                Age  DistanceFromHome    Education  MonthlyIncome  \
# count  3699.000000       3699.000000  3699.000000    3699.000000
# mean     37.561233          9.227088     2.919708   65672.595296
# std       8.885956          8.167978     1.025784   47472.814021
# min      18.000000          1.000000     1.000000   10510.000000
# 25%      31.000000          2.000000     2.000000   29360.000000
# 50%      36.000000          7.000000     3.000000   49300.000000
# 75%      43.000000         14.000000     4.000000   86060.000000
# max      60.000000         29.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         3684.000000        3699.000000        3692.000000
# mean             2.648480          15.157340          11.860780
# std              2.460537           3.634551           7.762536
# min              0.000000          11.000000           0.000000
# ...

# %%
df_2[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].sample(25).describe() #Taking a sample out of popultion of non-attrited employees
# Out:
#              Age  DistanceFromHome  Education  MonthlyIncome  \
# count  25.000000         25.000000  25.000000      25.000000
# mean   37.680000          7.760000   3.000000   59706.800000
# std     9.525055          6.514599   0.957427   41553.007685
# min    23.000000          1.000000   1.000000   20330.000000
# 25%    31.000000          3.000000   2.000000   38330.000000
# 50%    35.000000          4.000000   3.000000   45540.000000
# 75%    45.000000         14.000000   4.000000   64390.000000
# max    60.000000         20.000000   5.000000  190490.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count           25.000000          25.000000          25.000000
# mean             2.600000          16.200000          12.400000
# std              2.362908           4.232808           8.770215
# min              0.000000          11.000000           1.000000
# 25%              1.000000          13.000000           6.000000
# ...

# %%
#Number of Comapnies Worked more than 4

df_3 = df_1.loc[df_1['NumCompaniesWorked'] > 4]
df_3[['Age','DistanceFromHome','Education','MonthlyIncome',
 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
# Out:
#               Age  DistanceFromHome   Education  MonthlyIncome  \
# count  199.000000        199.000000  199.000000     199.000000
# mean    36.994975          8.552764    3.085427   58937.135678
# std      9.713833          7.114928    0.946945   46344.372070
# min     22.000000          1.000000    1.000000   10090.000000
# 25%     29.000000          2.000000    3.000000   27410.000000
# 50%     34.000000          7.000000    3.000000   45220.000000
# 75%     43.000000         11.500000    4.000000   67120.000000
# max     58.000000         28.000000    5.000000  196270.000000
#
#        PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# count         199.000000         199.000000             199.000000
# mean           15.844221          10.849246               2.562814
# std             4.134220           7.233996               1.203876
# min            11.000000           3.000000               0.000000
# ...

# %%
df_3[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].sample(100).describe()
# Out:
#               Age  DistanceFromHome   Education  MonthlyIncome  \
# count  100.000000        100.000000  100.000000     100.000000
# mean    37.290000          8.820000    3.070000   52819.900000
# std      9.935443          7.144087    0.901794   38061.193299
# min     22.000000          1.000000    1.000000   10090.000000
# 25%     30.000000          2.750000    2.750000   26130.000000
# 50%     33.500000          7.000000    3.000000   43755.000000
# 75%     43.250000         12.750000    4.000000   67040.000000
# max     58.000000         28.000000    5.000000  196270.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count           100.00000         100.000000         100.000000
# mean              6.70000          16.090000          11.690000
# std               1.38899           4.030427           7.248399
# min               5.00000          11.000000           3.000000
# 25%               5.00000          13.000000           6.750000
# ...

# %%
#Number of trainings taken last year more than 3

df_4 = df_1.loc[df_1['TrainingTimesLastYear'] > 3]
df_4[['Age','DistanceFromHome','Education','MonthlyIncome',
 'PercentSalaryHike','TotalWorkingYears',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
# Out:
#               Age  DistanceFromHome   Education  MonthlyIncome  \
# count  111.000000        111.000000  111.000000     111.000000
# mean    30.108108         12.108108    3.000000   58280.810811
# std      7.994716          8.263118    1.018019   45972.509773
# min     18.000000          1.000000    1.000000   17900.000000
# 25%     26.000000          6.000000    3.000000   28530.000000
# 50%     29.000000          9.000000    3.000000   36920.000000
# 75%     33.000000         19.000000    4.000000   66520.000000
# max     53.000000         29.000000    4.000000  187890.000000
#
#        PercentSalaryHike  TotalWorkingYears  YearsAtCompany  \
# count         111.000000         111.000000      111.000000
# mean           16.297297           6.270270        3.648649
# std             4.305587           4.508469        3.178475
# min            11.000000           0.000000        0.000000
# 25%            12.000000           4.000000        2.000000
# ...

# %%
df_4[['Age','DistanceFromHome','Education','MonthlyIncome',
 'PercentSalaryHike','TotalWorkingYears',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].sample(25).describe()
# Out:
#              Age  DistanceFromHome  Education  MonthlyIncome  \
# count  25.000000         25.000000  25.000000      25.000000
# mean   31.200000         14.160000   3.320000   51167.600000
# std     8.679478          8.711487   0.748331   38981.867075
# min    18.000000          2.000000   2.000000   22070.000000
# 25%    26.000000          7.000000   3.000000   28530.000000
# 50%    29.000000         11.000000   3.000000   34230.000000
# 75%    33.000000         19.000000   4.000000   52380.000000
# max    53.000000         29.000000   4.000000  157870.000000
#
#        PercentSalaryHike  TotalWorkingYears  YearsAtCompany  \
# count          25.000000          25.000000       25.000000
# mean           15.840000           6.680000        3.920000
# std             4.140048           5.161718        3.718423
# min            11.000000           0.000000        0.000000
# 25%            13.000000           4.000000        1.000000
# ...
